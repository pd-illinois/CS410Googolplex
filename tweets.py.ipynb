# %%
import json
import pandas as pd
import csv
from pandas.io.json import json_normalize

# %%
rawtweet = pd.read_json(r'election2022.json', lines=True)
rawtweet = rawtweet[rawtweet['lang']=='en']
print("Shape: ", rawtweet.shape)
print(rawtweet.head(5))
# Out:
# Shape:  (4134, 28)
#                             _type  \
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
# 5  snscrape.modules.twitter.Tweet
# 6  snscrape.modules.twitter.Tweet
# 7  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 3  https://twitter.com/kallieleyba/status/1586144...
# 4  https://twitter.com/nett_kelle/status/15861448...
# 5  https://twitter.com/RealMsTEWatson/status/1586...
# 6  https://twitter.com/theatlantavoice/status/158...
# 7  https://twitter.com/Cccccccolinator/status/158...
#
#                        date  \
# 3 2022-10-28 23:56:16+00:00
# 4 2022-10-28 23:56:04+00:00
# 5 2022-10-28 23:55:45+00:00
# 6 2022-10-28 23:54:13+00:00
# 7 2022-10-28 23:54:07+00:00
#
#                                              content  \
# 3  If y’all turn in your ballots they will run ou...
# 4  The people of this country should rally togeth...
# 5  Literally one of the most critical offices in ...
# 6  Here is the livestream of tonight's Democratic...
# 7  Wow @newsmax ...bring the big beautiful blue e...
#
#                                      renderedContent                   id  \
# 3  If y’all turn in your ballots they will run ou...  1586144851875094528
# 4  The people of this country should rally togeth...  1586144801770307584
# 5  Literally one of the most critical offices in ...  1586144720576970753
# 6  Here is the livestream of tonight's Democratic...  1586144337641066499
# 7  Wow @newsmax ...bring the big beautiful blue e...  1586144309996269568
#
#                                                 user  replyCount  \
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 5  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 6  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 7  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#    retweetCount  likeCount  ...  \
# 3             7         42  ...
# 4             0          7  ...
# 5             0          0  ...
# 6             1          2  ...
# 7             0          0  ...
#
#                                                media  retweetedTweet  \
# 3  [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 4                                               None             NaN
# 5                                               None             NaN
# 6                                               None             NaN
# 7                                               None             NaN
#
#                                          quotedTweet inReplyToTweetId  \
# 3                                               None              NaN
# 4                                               None              NaN
# 5  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 6                                               None              NaN
# 7                                               None              NaN
#
#   inReplyToUser                                     mentionedUsers  \
# 3          None  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 4          None                                               None
# 5          None                                               None
# 6          None                                               None
# 7          None  [{'_type': 'snscrape.modules.twitter.User', 'u...
#
#   coordinates place                                           hashtags  \
# 3        None  None                                     [Election2022]
# 4        None  None  [Midterms2022, MidtermElections2022, Election2...
# 5        None  None  [Texas, community, NotleyFellow, peoplebeforep...
# 6        None  None                              [GaPol, Election2022]
# 7        None  None                                     [Election2022]
#
#    cashtags
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
#
# [5 rows x 28 columns]

# %%
users = json_normalize(rawtweet['user'])
users.drop(['description', 'linkTcourl'], axis=1, inplace=True)
users.rename(columns={'id':'userId', 'url':'profileUrl'}, inplace=True)
users.head(5)
# Out:
# <ipython-input-6-82fa6ee92769>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   users = json_normalize(rawtweet['user'])
#                            _type         username               userId  \
# 0  snscrape.modules.twitter.User      kallieleyba             71367139
# 1  snscrape.modules.twitter.User       nett_kelle  1221805314481082368
# 2  snscrape.modules.twitter.User   RealMsTEWatson  1200259351312764929
# 3  snscrape.modules.twitter.User  theatlantavoice            199252851
# 4  snscrape.modules.twitter.User  Cccccccolinator            106599628
#
#             displayname                                     rawDescription  \
# 0          Kallie Leyba  Mother, wife, educator, dog lover, activist an...
# 1       Kelle Nett, PhD  PhD in Neuroscience from the University of Iow...
# 2  TaylorEWatsonSanAnto  A ginger in clogs on #TheMagicCivicsBus\nSocia...
# 3     The Atlanta Voice  Atlanta’s African American-owned and operated ...
# 4       Cccccccolinator  Jesus.   Rock and EDM music.   Conservative po...
#
#   descriptionUrls  verified                    created  followersCount  \
# 0            None     False  2009-09-03T21:41:52+00:00             595
# 1            None     False  2020-01-27T14:41:13+00:00             214
# 2            None     False  2019-11-29T03:45:17+00:00              52
# 3            None     False  2010-10-06T12:09:26+00:00            5997
# 4            None     False  2010-01-20T02:26:11+00:00              74
#
#    friendsCount  ...                     linkUrl  \
# 0           574  ...                        None
# 1           323  ...                        None
# 2           214  ...                        None
# 3          2301  ...  http://theatlantavoice.com
# 4           235  ...                        None
#
#                                      profileImageUrl  \
# 0  https://pbs.twimg.com/profile_images/149294278...
# 1  https://pbs.twimg.com/profile_images/155484310...
# 2  https://pbs.twimg.com/profile_images/158461657...
# 3  https://pbs.twimg.com/profile_images/147638375...
# 4  https://pbs.twimg.com/profile_images/158653298...
#
#                                     profileBannerUrl  label  \
# 0  https://pbs.twimg.com/profile_banners/71367139...    NaN
# 1  https://pbs.twimg.com/profile_banners/12218053...    NaN
# 2  https://pbs.twimg.com/profile_banners/12002593...    NaN
# 3  https://pbs.twimg.com/profile_banners/19925285...    NaN
# 4                                               None    NaN
#
#                             profileUrl  label._type label.description  \
# 0      https://twitter.com/kallieleyba          NaN               NaN
# 1       https://twitter.com/nett_kelle          NaN               NaN
# 2   https://twitter.com/RealMsTEWatson          NaN               NaN
# 3  https://twitter.com/theatlantavoice          NaN               NaN
# 4  https://twitter.com/Cccccccolinator          NaN               NaN
#
#   label.url label.badgeUrl  label.longDescription
# 0       NaN            NaN                    NaN
# 1       NaN            NaN                    NaN
# 2       NaN            NaN                    NaN
# 3       NaN            NaN                    NaN
# 4       NaN            NaN                    NaN
#
# [5 rows x 26 columns]

# %%
#with open('election2022.json', 'r') as electionfile:
#    tweets=electionfile.read()
#f = open('election2022.json')
#tweets = json.load(f)
#obj = json.load(electionfile)
#print(obj)

#df = pd.read_json('data.json')
#print(df.head(5))

#df = pd.DataFrame(response['json_response'])
#df.to_csv('data.csv')
#fileName = 'electionsdata'
#csvFile = open(fileName, "a", newline="", encoding='utf-8')
#csvWriter = csv.writer(csvFile)

#for tweet in data:
    #print(tweet)
    #author_id = tweet['author_id']
    #source = tweet['source']
    #tweet_id = tweet['id']
    #text = tweet['text']
    #res = [author_id, created_at, geo, tweet_id, lang, like_count, quote_count, reply_count, retweet_count, source, text]
    #res = [author_id, tweet_id, source, text]
    #csvWriter.writerow(res)
    #counter += 1
#csvFile.close()


#csvFile = open('election2022.json', 'a')
#csvWriter = csv.writer(csvFile)

#print(tweets[0])
#attributes_container = [[tweet.user.username, tweet.user.description, tweet.user.created, tweet.user.location] for tweet in tweets]

#Creation of column list to rename the columns in the dataframe
#columns = ["username", "description", "CreatedAt", "Location"]
    
#Creation of Dataframe
#tweets_df = pd.DataFrame(attributes_container, columns=columns)
#f.close()
#print(tweets_df)
